# %% [markdown]
# # REVIEW QUESTION 1

# %%
Cardinal_numbers = ('First', 'Second', 'Third')

print("The string index 1 at Cardinal numbers is '" + Cardinal_numbers[1] + "'")
# Out:
# The string index 1 at Cardinal numbers is 'Second'

# %%
Position1, Position2, Position3 = Cardinal_numbers

print(Position1)
print(Position2)
print(Position3)
# Out:
# First
# Second
# Third

# %%
My_ngan = tuple("Joren Jay L. Bulahan")

print(type(My_ngan))
print(My_ngan)
# Out:
# <class 'tuple'>
# ('J', 'o', 'r', 'e', 'n', ' ', 'J', 'a', 'y', ' ', 'L', '.', ' ', 'B', 'u', 'l', 'a', 'h', 'a', 'n')

# %%
if 'x' in My_ngan:
    print("Character 'x' is in the name")
else:
    print("Character 'x' is not in the name")
# Out:
# Character 'x' is not in the name

# %%
print(My_ngan[1:])
# Out:
# ('o', 'r', 'e', 'n', ' ', 'J', 'a', 'y', ' ', 'L', '.', ' ', 'B', 'u', 'l', 'a', 'h', 'a', 'n')
